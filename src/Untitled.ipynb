# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# !make
# !./main
soln = genfromtxt("solution.txt")
forc = genfromtxt("forcing.txt")
# Out:
# [ 66%] Built target heat
# [100%] Built target main
# Running heat solver
# Total time = 1
# dt = 0.1
# num timesteps = 10
# 0.2 0.txt
# 0.4 1.txt
# 0.6 2.txt
# 0.8 3.txt
# 1 4.txt

# %%
pcolormesh(soln)
axis('tight')
figure()
pcolormesh(forc)
axis('tight')
# Out:
# (0.0, 300.0, 0.0, 300.0)

# %%
for i in range(5):
    soln = genfromtxt('%d.txt'%i)
    figure()
    pcolormesh(soln)
