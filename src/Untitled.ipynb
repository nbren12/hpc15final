# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
for i in range(20):
    soln = genfromtxt('%07d.txt'%i)
    figure()
    pcolormesh(soln)
# Out:
# /Users/noah/anaconda/lib/python3.4/site-packages/matplotlib/colors.py:584: RuntimeWarning: invalid value encountered in less
#   cbook._putmask(xa, xa < 0.0, -1)
